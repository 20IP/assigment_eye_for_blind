# %%
import os
import numpy as np
import cv2
import glob
import imutils
import pandas as pd
import matplotlib.pyplot as plt
import random
from function import show_img_desc

# %%
# Count total images
total_images = glob.glob('Images/*.*')
len(total_images)
# Out:
# 8091

# %%
df_text = pd.read_csv('captions.txt', sep = ',')
df_text.head()
# Out:
#                        image  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0  A child in a pink dress is climbing up a set o...
# 1              A girl going into a wooden building .
# 2   A little girl climbing into a wooden playhouse .
# 3  A little girl climbing the stairs to her playh...
# 4  A little girl in a pink dress going into a woo...

# %%
len(df_text['image'].unique())
# Out:
# 8091

# %%
show_img_desc(total_images, df_text, 4)
# Out:
# Four children playing basketball .
# Four people are playing basketball on a plank deck outdoors .
# Four people playing basketball on wooden area near the beach .
# Kids playing basketball on a wood deck .
# Young children shoot baskets in the field .
# a black and white dog jumping in the air to get a toy .
# A black and white dog jumps up towards a yellow toy .
# A dog leaps to catch a ball in a field .
# A white dog is trying to catch a ball in midair over a grassy field .
# The white dog is playing in a green field with a yellow toy .
# A bug sits on a girls finger while she looks shocked .
# A girl in a school uniform screams with a bug on her finger .
# A girl looks at a bug on her finger and looks scared .
# A young girl makes a face as she looks at an insect on her finger .
# The girl with glasses on has a bug on her right pointer finger .
# A boy wearing a red shirt jumps off the blue slide .
# A little boy in a red t-shirt jumps off of a blue slide at a playground .
# ...
